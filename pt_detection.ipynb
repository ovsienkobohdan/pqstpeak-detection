# %% [markdown]
# <a href="https://colab.research.google.com/github/ovsienkobohdan/pqstpeak-detection/blob/main/pt_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Input

# %%
# !pip install wfdb

# %%
# !pip install biosppy

# %%
import h5py

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import scipy.signal as signal
import pywt

import wfdb
import os

from biosppy import storage
from biosppy.signals import ecg

from sklearn.metrics import mean_absolute_error
# Out:
# Running cells with 'Python 3.10.4 ('pqstpeak-detection')' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/Users/x/.virtualenvs/pqstpeak-detection/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# !wget -r -N -c -np https://physionet.org/files/qtdb/1.0.0/
# Out:
# Streaming output truncated to the last 5000 lines.
#
# --2020-08-29 09:59:19--  https://physionet.org/files/qtdb/1.0.0/sel52.qt1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 668 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel52.qt1’
#
# physionet.org/files 100%[===================>]     668  --.-KB/s    in 0s
#
# 2020-08-29 09:59:19 (127 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel52.qt1’ saved [668/668]
#
# --2020-08-29 09:59:19--  https://physionet.org/files/qtdb/1.0.0/sel52.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 90 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel52.xws’
#
# physionet.org/files 100%[===================>]      90  --.-KB/s    in 0s
#
# 2020-08-29 09:59:20 (4.58 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel52.xws’ saved [90/90]
#
# --2020-08-29 09:59:20--  https://physionet.org/files/qtdb/1.0.0/sel803.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2054 (2.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel803.atr’
#
# physionet.org/files 100%[===================>]   2.01K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:20 (395 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel803.atr’ saved [2054/2054]
#
# --2020-08-29 09:59:20--  https://physionet.org/files/qtdb/1.0.0/sel803.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674997 (659K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel803.dat’
#
# physionet.org/files 100%[===================>] 659.18K  --.-KB/s    in 0.07s
#
# 2020-08-29 09:59:20 (9.86 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel803.dat’ saved [674997/674997]
#
# --2020-08-29 09:59:20--  https://physionet.org/files/qtdb/1.0.0/sel803.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 161 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel803.hea’
#
# physionet.org/files 100%[===================>]     161  --.-KB/s    in 0s
#
# 2020-08-29 09:59:20 (25.1 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel803.hea’ saved [161/161]
#
# --2020-08-29 09:59:20--  https://physionet.org/files/qtdb/1.0.0/sel803.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 193 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel803.hea-’
#
# physionet.org/files 100%[===================>]     193  --.-KB/s    in 0s
#
# 2020-08-29 09:59:21 (36.6 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel803.hea-’ saved [193/193]
#
# --2020-08-29 09:59:21--  https://physionet.org/files/qtdb/1.0.0/sel803.man
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel803.man’
#
# physionet.org/files 100%[===================>]      70  --.-KB/s    in 0s
#
# 2020-08-29 09:59:21 (13.2 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel803.man’ saved [70/70]
#
# --2020-08-29 09:59:21--  https://physionet.org/files/qtdb/1.0.0/sel803.pu
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 80680 (79K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel803.pu’
#
# physionet.org/files 100%[===================>]  78.79K  --.-KB/s    in 0.007s
#
# 2020-08-29 09:59:21 (11.4 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel803.pu’ saved [80680/80680]
#
# --2020-08-29 09:59:21--  https://physionet.org/files/qtdb/1.0.0/sel803.pu0
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 32242 (31K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel803.pu0’
#
# physionet.org/files 100%[===================>]  31.49K  --.-KB/s    in 0.002s
#
# 2020-08-29 09:59:21 (15.0 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel803.pu0’ saved [32242/32242]
#
# --2020-08-29 09:59:21--  https://physionet.org/files/qtdb/1.0.0/sel803.pu1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 32374 (32K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel803.pu1’
#
# physionet.org/files 100%[===================>]  31.62K  --.-KB/s    in 0.001s
#
# 2020-08-29 09:59:22 (39.9 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel803.pu1’ saved [32374/32374]
#
# --2020-08-29 09:59:22--  https://physionet.org/files/qtdb/1.0.0/sel803.q1c
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 726 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel803.q1c’
#
# physionet.org/files 100%[===================>]     726  --.-KB/s    in 0s
#
# 2020-08-29 09:59:22 (108 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel803.q1c’ saved [726/726]
#
# --2020-08-29 09:59:22--  https://physionet.org/files/qtdb/1.0.0/sel803.qt1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel803.qt1’
#
# physionet.org/files 100%[===================>]     608  --.-KB/s    in 0s
#
# 2020-08-29 09:59:22 (94.5 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel803.qt1’ saved [608/608]
#
# --2020-08-29 09:59:22--  https://physionet.org/files/qtdb/1.0.0/sel803.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel803.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2020-08-29 09:59:22 (16.5 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel803.xws’ saved [91/91]
#
# --2020-08-29 09:59:22--  https://physionet.org/files/qtdb/1.0.0/sel808.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1814 (1.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel808.atr’
#
# physionet.org/files 100%[===================>]   1.77K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:23 (255 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel808.atr’ saved [1814/1814]
#
# --2020-08-29 09:59:23--  https://physionet.org/files/qtdb/1.0.0/sel808.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674997 (659K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel808.dat’
#
# physionet.org/files 100%[===================>] 659.18K  --.-KB/s    in 0.07s
#
# 2020-08-29 09:59:23 (8.76 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel808.dat’ saved [674997/674997]
#
# --2020-08-29 09:59:23--  https://physionet.org/files/qtdb/1.0.0/sel808.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 163 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel808.hea’
#
# physionet.org/files 100%[===================>]     163  --.-KB/s    in 0s
#
# 2020-08-29 09:59:23 (32.5 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel808.hea’ saved [163/163]
#
# --2020-08-29 09:59:23--  https://physionet.org/files/qtdb/1.0.0/sel808.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 195 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel808.hea-’
#
# physionet.org/files 100%[===================>]     195  --.-KB/s    in 0s
#
# 2020-08-29 09:59:23 (36.7 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel808.hea-’ saved [195/195]
#
# --2020-08-29 09:59:23--  https://physionet.org/files/qtdb/1.0.0/sel808.man
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel808.man’
#
# physionet.org/files 100%[===================>]      70  --.-KB/s    in 0s
#
# 2020-08-29 09:59:24 (5.85 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel808.man’ saved [70/70]
#
# --2020-08-29 09:59:24--  https://physionet.org/files/qtdb/1.0.0/sel808.pu
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 73692 (72K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel808.pu’
#
# physionet.org/files 100%[===================>]  71.96K  --.-KB/s    in 0.007s
#
# 2020-08-29 09:59:24 (9.39 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel808.pu’ saved [73692/73692]
#
# --2020-08-29 09:59:24--  https://physionet.org/files/qtdb/1.0.0/sel808.pu0
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 28912 (28K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel808.pu0’
#
# physionet.org/files 100%[===================>]  28.23K  --.-KB/s    in 0.001s
#
# 2020-08-29 09:59:24 (23.4 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel808.pu0’ saved [28912/28912]
#
# --2020-08-29 09:59:24--  https://physionet.org/files/qtdb/1.0.0/sel808.pu1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 28850 (28K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel808.pu1’
#
# physionet.org/files 100%[===================>]  28.17K  --.-KB/s    in 0.001s
#
# 2020-08-29 09:59:25 (20.5 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel808.pu1’ saved [28850/28850]
#
# --2020-08-29 09:59:25--  https://physionet.org/files/qtdb/1.0.0/sel808.q1c
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 966 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel808.q1c’
#
# physionet.org/files 100%[===================>]     966  --.-KB/s    in 0s
#
# 2020-08-29 09:59:25 (174 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel808.q1c’ saved [966/966]
#
# --2020-08-29 09:59:25--  https://physionet.org/files/qtdb/1.0.0/sel808.qt1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 728 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel808.qt1’
#
# physionet.org/files 100%[===================>]     728  --.-KB/s    in 0s
#
# 2020-08-29 09:59:25 (115 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel808.qt1’ saved [728/728]
#
# --2020-08-29 09:59:25--  https://physionet.org/files/qtdb/1.0.0/sel808.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel808.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2020-08-29 09:59:25 (15.3 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel808.xws’ saved [91/91]
#
# --2020-08-29 09:59:25--  https://physionet.org/files/qtdb/1.0.0/sel811.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1410 (1.4K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel811.atr’
#
# physionet.org/files 100%[===================>]   1.38K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:26 (228 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel811.atr’ saved [1410/1410]
#
# --2020-08-29 09:59:26--  https://physionet.org/files/qtdb/1.0.0/sel811.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674997 (659K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel811.dat’
#
# physionet.org/files 100%[===================>] 659.18K  --.-KB/s    in 0.1s
#
# 2020-08-29 09:59:26 (5.05 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel811.dat’ saved [674997/674997]
#
# --2020-08-29 09:59:26--  https://physionet.org/files/qtdb/1.0.0/sel811.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 167 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel811.hea’
#
# physionet.org/files 100%[===================>]     167  --.-KB/s    in 0s
#
# 2020-08-29 09:59:26 (28.0 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel811.hea’ saved [167/167]
#
# --2020-08-29 09:59:26--  https://physionet.org/files/qtdb/1.0.0/sel811.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 199 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel811.hea-’
#
# physionet.org/files 100%[===================>]     199  --.-KB/s    in 0s
#
# 2020-08-29 09:59:28 (33.8 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel811.hea-’ saved [199/199]
#
# --2020-08-29 09:59:28--  https://physionet.org/files/qtdb/1.0.0/sel811.man
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel811.man’
#
# physionet.org/files 100%[===================>]      70  --.-KB/s    in 0s
#
# 2020-08-29 09:59:29 (11.1 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel811.man’ saved [70/70]
#
# --2020-08-29 09:59:29--  https://physionet.org/files/qtdb/1.0.0/sel811.pu
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 56894 (56K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel811.pu’
#
# physionet.org/files 100%[===================>]  55.56K  --.-KB/s    in 0.02s
#
# 2020-08-29 09:59:29 (2.19 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel811.pu’ saved [56894/56894]
#
# --2020-08-29 09:59:29--  https://physionet.org/files/qtdb/1.0.0/sel811.pu0
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22364 (22K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel811.pu0’
#
# physionet.org/files 100%[===================>]  21.84K  --.-KB/s    in 0.005s
#
# 2020-08-29 09:59:29 (4.38 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel811.pu0’ saved [22364/22364]
#
# --2020-08-29 09:59:29--  https://physionet.org/files/qtdb/1.0.0/sel811.pu1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22440 (22K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel811.pu1’
#
# physionet.org/files 100%[===================>]  21.91K  --.-KB/s    in 0.002s
#
# 2020-08-29 09:59:30 (9.65 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel811.pu1’ saved [22440/22440]
#
# --2020-08-29 09:59:30--  https://physionet.org/files/qtdb/1.0.0/sel811.q1c
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 730 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel811.q1c’
#
# physionet.org/files 100%[===================>]     730  --.-KB/s    in 0s
#
# 2020-08-29 09:59:30 (138 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel811.q1c’ saved [730/730]
#
# --2020-08-29 09:59:30--  https://physionet.org/files/qtdb/1.0.0/sel811.qt1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 604 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel811.qt1’
#
# physionet.org/files 100%[===================>]     604  --.-KB/s    in 0s
#
# 2020-08-29 09:59:31 (121 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel811.qt1’ saved [604/604]
#
# --2020-08-29 09:59:31--  https://physionet.org/files/qtdb/1.0.0/sel811.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel811.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2020-08-29 09:59:31 (17.9 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel811.xws’ saved [91/91]
#
# --2020-08-29 09:59:31--  https://physionet.org/files/qtdb/1.0.0/sel820.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2330 (2.3K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel820.atr’
#
# physionet.org/files 100%[===================>]   2.28K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:31 (409 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel820.atr’ saved [2330/2330]
#
# --2020-08-29 09:59:31--  https://physionet.org/files/qtdb/1.0.0/sel820.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674997 (659K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel820.dat’
#
# physionet.org/files 100%[===================>] 659.18K  1.06MB/s    in 0.6s
#
# 2020-08-29 09:59:32 (1.06 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel820.dat’ saved [674997/674997]
#
# --2020-08-29 09:59:32--  https://physionet.org/files/qtdb/1.0.0/sel820.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 155 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel820.hea’
#
# physionet.org/files 100%[===================>]     155  --.-KB/s    in 0s
#
# 2020-08-29 09:59:33 (26.7 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel820.hea’ saved [155/155]
#
# --2020-08-29 09:59:33--  https://physionet.org/files/qtdb/1.0.0/sel820.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 187 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel820.hea-’
#
# physionet.org/files 100%[===================>]     187  --.-KB/s    in 0s
#
# 2020-08-29 09:59:33 (35.1 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel820.hea-’ saved [187/187]
#
# --2020-08-29 09:59:33--  https://physionet.org/files/qtdb/1.0.0/sel820.man
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel820.man’
#
# physionet.org/files 100%[===================>]      70  --.-KB/s    in 0s
#
# 2020-08-29 09:59:33 (10.4 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel820.man’ saved [70/70]
#
# --2020-08-29 09:59:33--  https://physionet.org/files/qtdb/1.0.0/sel820.pu
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 95430 (93K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel820.pu’
#
# physionet.org/files 100%[===================>]  93.19K  --.-KB/s    in 0.02s
#
# 2020-08-29 09:59:33 (4.51 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel820.pu’ saved [95430/95430]
#
# --2020-08-29 09:59:33--  https://physionet.org/files/qtdb/1.0.0/sel820.pu0
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 36598 (36K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel820.pu0’
#
# physionet.org/files 100%[===================>]  35.74K  --.-KB/s    in 0.003s
#
# 2020-08-29 09:59:34 (12.5 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel820.pu0’ saved [36598/36598]
#
# --2020-08-29 09:59:34--  https://physionet.org/files/qtdb/1.0.0/sel820.pu1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 36756 (36K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel820.pu1’
#
# physionet.org/files 100%[===================>]  35.89K  --.-KB/s    in 0.004s
#
# 2020-08-29 09:59:34 (9.11 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel820.pu1’ saved [36756/36756]
#
# --2020-08-29 09:59:34--  https://physionet.org/files/qtdb/1.0.0/sel820.q1c
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 726 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel820.q1c’
#
# physionet.org/files 100%[===================>]     726  --.-KB/s    in 0s
#
# 2020-08-29 09:59:35 (136 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel820.q1c’ saved [726/726]
#
# --2020-08-29 09:59:35--  https://physionet.org/files/qtdb/1.0.0/sel820.qt1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel820.qt1’
#
# physionet.org/files 100%[===================>]     608  --.-KB/s    in 0s
#
# 2020-08-29 09:59:35 (114 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel820.qt1’ saved [608/608]
#
# --2020-08-29 09:59:35--  https://physionet.org/files/qtdb/1.0.0/sel820.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel820.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2020-08-29 09:59:35 (16.1 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel820.xws’ saved [91/91]
#
# --2020-08-29 09:59:35--  https://physionet.org/files/qtdb/1.0.0/sel821.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3116 (3.0K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel821.atr’
#
# physionet.org/files 100%[===================>]   3.04K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:36 (523 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel821.atr’ saved [3116/3116]
#
# --2020-08-29 09:59:36--  https://physionet.org/files/qtdb/1.0.0/sel821.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674997 (659K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel821.dat’
#
# physionet.org/files 100%[===================>] 659.18K  1.54MB/s    in 0.4s
#
# 2020-08-29 09:59:36 (1.54 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel821.dat’ saved [674997/674997]
#
# --2020-08-29 09:59:36--  https://physionet.org/files/qtdb/1.0.0/sel821.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 159 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel821.hea’
#
# physionet.org/files 100%[===================>]     159  --.-KB/s    in 0s
#
# 2020-08-29 09:59:37 (25.4 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel821.hea’ saved [159/159]
#
# --2020-08-29 09:59:37--  https://physionet.org/files/qtdb/1.0.0/sel821.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 191 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel821.hea-’
#
# physionet.org/files 100%[===================>]     191  --.-KB/s    in 0s
#
# 2020-08-29 09:59:37 (25.2 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel821.hea-’ saved [191/191]
#
# --2020-08-29 09:59:37--  https://physionet.org/files/qtdb/1.0.0/sel821.man
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel821.man’
#
# physionet.org/files 100%[===================>]      70  --.-KB/s    in 0s
#
# 2020-08-29 09:59:37 (14.3 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel821.man’ saved [70/70]
#
# --2020-08-29 09:59:37--  https://physionet.org/files/qtdb/1.0.0/sel821.pu
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 114294 (112K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel821.pu’
#
# physionet.org/files 100%[===================>] 111.62K  --.-KB/s    in 0.02s
#
# 2020-08-29 09:59:38 (6.94 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel821.pu’ saved [114294/114294]
#
# --2020-08-29 09:59:38--  https://physionet.org/files/qtdb/1.0.0/sel821.pu0
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 48754 (48K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel821.pu0’
#
# physionet.org/files 100%[===================>]  47.61K  --.-KB/s    in 0.004s
#
# 2020-08-29 09:59:38 (10.7 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel821.pu0’ saved [48754/48754]
#
# --2020-08-29 09:59:38--  https://physionet.org/files/qtdb/1.0.0/sel821.pu1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 44598 (44K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel821.pu1’
#
# physionet.org/files 100%[===================>]  43.55K  --.-KB/s    in 0.005s
#
# 2020-08-29 09:59:38 (9.15 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel821.pu1’ saved [44598/44598]
#
# --2020-08-29 09:59:38--  https://physionet.org/files/qtdb/1.0.0/sel821.q1c
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 814 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel821.q1c’
#
# physionet.org/files 100%[===================>]     814  --.-KB/s    in 0s
#
# 2020-08-29 09:59:38 (155 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel821.q1c’ saved [814/814]
#
# --2020-08-29 09:59:38--  https://physionet.org/files/qtdb/1.0.0/sel821.qt1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 644 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel821.qt1’
#
# physionet.org/files 100%[===================>]     644  --.-KB/s    in 0s
#
# 2020-08-29 09:59:39 (112 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel821.qt1’ saved [644/644]
#
# --2020-08-29 09:59:39--  https://physionet.org/files/qtdb/1.0.0/sel821.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel821.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2020-08-29 09:59:40 (15.3 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel821.xws’ saved [91/91]
#
# --2020-08-29 09:59:40--  https://physionet.org/files/qtdb/1.0.0/sel840.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2368 (2.3K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel840.atr’
#
# physionet.org/files 100%[===================>]   2.31K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:41 (424 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel840.atr’ saved [2368/2368]
#
# --2020-08-29 09:59:41--  https://physionet.org/files/qtdb/1.0.0/sel840.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674997 (659K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel840.dat’
#
# physionet.org/files 100%[===================>] 659.18K  2.26MB/s    in 0.3s
#
# 2020-08-29 09:59:41 (2.26 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel840.dat’ saved [674997/674997]
#
# --2020-08-29 09:59:41--  https://physionet.org/files/qtdb/1.0.0/sel840.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 166 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel840.hea’
#
# physionet.org/files 100%[===================>]     166  --.-KB/s    in 0s
#
# 2020-08-29 09:59:41 (28.4 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel840.hea’ saved [166/166]
#
# --2020-08-29 09:59:41--  https://physionet.org/files/qtdb/1.0.0/sel840.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 198 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel840.hea-’
#
# physionet.org/files 100%[===================>]     198  --.-KB/s    in 0s
#
# 2020-08-29 09:59:42 (33.4 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel840.hea-’ saved [198/198]
#
# --2020-08-29 09:59:42--  https://physionet.org/files/qtdb/1.0.0/sel840.man
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 180 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel840.man’
#
# physionet.org/files 100%[===================>]     180  --.-KB/s    in 0s
#
# 2020-08-29 09:59:42 (35.3 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel840.man’ saved [180/180]
#
# --2020-08-29 09:59:42--  https://physionet.org/files/qtdb/1.0.0/sel840.pu
# Connecting to physionet.org (physionet.org)|18.13.52.205|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90092 (88K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel840.pu’
#
# physionet.org/files 100%[===================>]  87.98K   227KB/s    in 0.4s
#
# 2020-08-29 09:59:43 (227 KB/s) - ‘physionet.org/files/qtdb/1.0.0/sel840.pu’ saved [90092/90092]
#
# --2020-08-29 09:59:43--  https://physionet.org/files/qtdb/1.0.0/sel840.pu0
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 35956 (35K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel840.pu0’
#
# physionet.org/files 100%[===================>]  35.11K  --.-KB/s    in 0.02s
#
# 2020-08-29 09:59:44 (1.76 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel840.pu0’ saved [35956/35956]
#
# --2020-08-29 09:59:44--  https://physionet.org/files/qtdb/1.0.0/sel840.pu1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 36534 (36K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel840.pu1’
#
# physionet.org/files 100%[===================>]  35.68K  --.-KB/s    in 0.02s
#
# 2020-08-29 09:59:44 (1.75 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel840.pu1’ saved [36534/36534]
#
# --2020-08-29 09:59:44--  https://physionet.org/files/qtdb/1.0.0/sel840.q1c
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1960 (1.9K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel840.q1c’
#
# physionet.org/files 100%[===================>]   1.91K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:45 (387 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel840.q1c’ saved [1960/1960]
#
# --2020-08-29 09:59:45--  https://physionet.org/files/qtdb/1.0.0/sel840.qt1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1428 (1.4K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel840.qt1’
#
# physionet.org/files 100%[===================>]   1.39K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:46 (233 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel840.qt1’ saved [1428/1428]
#
# --2020-08-29 09:59:46--  https://physionet.org/files/qtdb/1.0.0/sel840.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel840.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2020-08-29 09:59:46 (15.8 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel840.xws’ saved [91/91]
#
# --2020-08-29 09:59:46--  https://physionet.org/files/qtdb/1.0.0/sel847.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1614 (1.6K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel847.atr’
#
# physionet.org/files 100%[===================>]   1.58K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:47 (259 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel847.atr’ saved [1614/1614]
#
# --2020-08-29 09:59:47--  https://physionet.org/files/qtdb/1.0.0/sel847.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674997 (659K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel847.dat’
#
# physionet.org/files 100%[===================>] 659.18K   962KB/s    in 0.7s
#
# 2020-08-29 09:59:48 (962 KB/s) - ‘physionet.org/files/qtdb/1.0.0/sel847.dat’ saved [674997/674997]
#
# --2020-08-29 09:59:48--  https://physionet.org/files/qtdb/1.0.0/sel847.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 164 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel847.hea’
#
# physionet.org/files 100%[===================>]     164  --.-KB/s    in 0s
#
# 2020-08-29 09:59:48 (26.5 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel847.hea’ saved [164/164]
#
# --2020-08-29 09:59:48--  https://physionet.org/files/qtdb/1.0.0/sel847.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 196 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel847.hea-’
#
# physionet.org/files 100%[===================>]     196  --.-KB/s    in 0s
#
# 2020-08-29 09:59:48 (32.3 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel847.hea-’ saved [196/196]
#
# --2020-08-29 09:59:48--  https://physionet.org/files/qtdb/1.0.0/sel847.man
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 102 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel847.man’
#
# physionet.org/files 100%[===================>]     102  --.-KB/s    in 0s
#
# 2020-08-29 09:59:49 (18.6 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel847.man’ saved [102/102]
#
# --2020-08-29 09:59:49--  https://physionet.org/files/qtdb/1.0.0/sel847.pu
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 65056 (64K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel847.pu’
#
# physionet.org/files 100%[===================>]  63.53K  --.-KB/s    in 0.008s
#
# 2020-08-29 09:59:49 (7.86 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel847.pu’ saved [65056/65056]
#
# --2020-08-29 09:59:49--  https://physionet.org/files/qtdb/1.0.0/sel847.pu0
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 25382 (25K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel847.pu0’
#
# physionet.org/files 100%[===================>]  24.79K  --.-KB/s    in 0.002s
#
# 2020-08-29 09:59:49 (11.7 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel847.pu0’ saved [25382/25382]
#
# --2020-08-29 09:59:49--  https://physionet.org/files/qtdb/1.0.0/sel847.pu1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 26234 (26K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel847.pu1’
#
# physionet.org/files 100%[===================>]  25.62K  --.-KB/s    in 0.002s
#
# 2020-08-29 09:59:50 (14.5 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel847.pu1’ saved [26234/26234]
#
# --2020-08-29 09:59:50--  https://physionet.org/files/qtdb/1.0.0/sel847.q1c
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 822 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel847.q1c’
#
# physionet.org/files 100%[===================>]     822  --.-KB/s    in 0s
#
# 2020-08-29 09:59:50 (150 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel847.q1c’ saved [822/822]
#
# --2020-08-29 09:59:50--  https://physionet.org/files/qtdb/1.0.0/sel847.qt1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 680 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel847.qt1’
#
# physionet.org/files 100%[===================>]     680  --.-KB/s    in 0s
#
# 2020-08-29 09:59:50 (89.4 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel847.qt1’ saved [680/680]
#
# --2020-08-29 09:59:50--  https://physionet.org/files/qtdb/1.0.0/sel847.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel847.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2020-08-29 09:59:50 (17.1 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel847.xws’ saved [91/91]
#
# --2020-08-29 09:59:50--  https://physionet.org/files/qtdb/1.0.0/sel853.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2258 (2.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel853.atr’
#
# physionet.org/files 100%[===================>]   2.21K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:50 (249 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel853.atr’ saved [2258/2258]
#
# --2020-08-29 09:59:50--  https://physionet.org/files/qtdb/1.0.0/sel853.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674997 (659K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel853.dat’
#
# physionet.org/files 100%[===================>] 659.18K  2.32MB/s    in 0.3s
#
# 2020-08-29 09:59:51 (2.32 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel853.dat’ saved [674997/674997]
#
# --2020-08-29 09:59:51--  https://physionet.org/files/qtdb/1.0.0/sel853.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 162 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel853.hea’
#
# physionet.org/files 100%[===================>]     162  --.-KB/s    in 0s
#
# 2020-08-29 09:59:51 (27.9 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel853.hea’ saved [162/162]
#
# --2020-08-29 09:59:51--  https://physionet.org/files/qtdb/1.0.0/sel853.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 194 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel853.hea-’
#
# physionet.org/files 100%[===================>]     194  --.-KB/s    in 0s
#
# 2020-08-29 09:59:51 (30.9 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel853.hea-’ saved [194/194]
#
# --2020-08-29 09:59:51--  https://physionet.org/files/qtdb/1.0.0/sel853.man
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel853.man’
#
# physionet.org/files 100%[===================>]      70  --.-KB/s    in 0s
#
# 2020-08-29 09:59:52 (12.2 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel853.man’ saved [70/70]
#
# --2020-08-29 09:59:52--  https://physionet.org/files/qtdb/1.0.0/sel853.pu
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 89988 (88K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel853.pu’
#
# physionet.org/files 100%[===================>]  87.88K  --.-KB/s    in 0.008s
#
# 2020-08-29 09:59:52 (10.7 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel853.pu’ saved [89988/89988]
#
# --2020-08-29 09:59:52--  https://physionet.org/files/qtdb/1.0.0/sel853.pu0
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 34886 (34K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel853.pu0’
#
# physionet.org/files 100%[===================>]  34.07K  --.-KB/s    in 0.003s
#
# 2020-08-29 09:59:52 (11.2 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel853.pu0’ saved [34886/34886]
#
# --2020-08-29 09:59:52--  https://physionet.org/files/qtdb/1.0.0/sel853.pu1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 34620 (34K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel853.pu1’
#
# physionet.org/files 100%[===================>]  33.81K  --.-KB/s    in 0.001s
#
# 2020-08-29 09:59:53 (24.8 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel853.pu1’ saved [34620/34620]
#
# --2020-08-29 09:59:53--  https://physionet.org/files/qtdb/1.0.0/sel853.q1c
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 726 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel853.q1c’
#
# physionet.org/files 100%[===================>]     726  --.-KB/s    in 0s
#
# 2020-08-29 09:59:53 (137 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel853.q1c’ saved [726/726]
#
# --2020-08-29 09:59:53--  https://physionet.org/files/qtdb/1.0.0/sel853.qt1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel853.qt1’
#
# physionet.org/files 100%[===================>]     608  --.-KB/s    in 0s
#
# 2020-08-29 09:59:53 (98.0 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel853.qt1’ saved [608/608]
#
# --2020-08-29 09:59:53--  https://physionet.org/files/qtdb/1.0.0/sel853.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel853.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2020-08-29 09:59:53 (14.0 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel853.xws’ saved [91/91]
#
# --2020-08-29 09:59:53--  https://physionet.org/files/qtdb/1.0.0/sel871.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1836 (1.8K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel871.atr’
#
# physionet.org/files 100%[===================>]   1.79K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:54 (121 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel871.atr’ saved [1836/1836]
#
# --2020-08-29 09:59:54--  https://physionet.org/files/qtdb/1.0.0/sel871.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674997 (659K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel871.dat’
#
# physionet.org/files 100%[===================>] 659.18K  --.-KB/s    in 0.09s
#
# 2020-08-29 09:59:54 (7.41 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel871.dat’ saved [674997/674997]
#
# --2020-08-29 09:59:54--  https://physionet.org/files/qtdb/1.0.0/sel871.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 167 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel871.hea’
#
# physionet.org/files 100%[===================>]     167  --.-KB/s    in 0s
#
# 2020-08-29 09:59:54 (28.8 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel871.hea’ saved [167/167]
#
# --2020-08-29 09:59:54--  https://physionet.org/files/qtdb/1.0.0/sel871.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 199 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel871.hea-’
#
# physionet.org/files 100%[===================>]     199  --.-KB/s    in 0s
#
# 2020-08-29 09:59:54 (36.0 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel871.hea-’ saved [199/199]
#
# --2020-08-29 09:59:54--  https://physionet.org/files/qtdb/1.0.0/sel871.man
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 260 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel871.man’
#
# physionet.org/files 100%[===================>]     260  --.-KB/s    in 0s
#
# 2020-08-29 09:59:55 (37.1 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel871.man’ saved [260/260]
#
# --2020-08-29 09:59:55--  https://physionet.org/files/qtdb/1.0.0/sel871.pu
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 74822 (73K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel871.pu’
#
# physionet.org/files 100%[===================>]  73.07K  --.-KB/s    in 0.004s
#
# 2020-08-29 09:59:55 (17.0 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel871.pu’ saved [74822/74822]
#
# --2020-08-29 09:59:55--  https://physionet.org/files/qtdb/1.0.0/sel871.pu0
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 29508 (29K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel871.pu0’
#
# physionet.org/files 100%[===================>]  28.82K  --.-KB/s    in 0.001s
#
# 2020-08-29 09:59:55 (28.2 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel871.pu0’ saved [29508/29508]
#
# --2020-08-29 09:59:55--  https://physionet.org/files/qtdb/1.0.0/sel871.pu1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 29442 (29K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel871.pu1’
#
# physionet.org/files 100%[===================>]  28.75K  --.-KB/s    in 0.004s
#
# 2020-08-29 09:59:55 (7.51 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel871.pu1’ saved [29442/29442]
#
# --2020-08-29 09:59:55--  https://physionet.org/files/qtdb/1.0.0/sel871.q1c
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1940 (1.9K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel871.q1c’
#
# physionet.org/files 100%[===================>]   1.89K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:56 (340 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel871.q1c’ saved [1940/1940]
#
# --2020-08-29 09:59:56--  https://physionet.org/files/qtdb/1.0.0/sel871.qt1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1462 (1.4K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel871.qt1’
#
# physionet.org/files 100%[===================>]   1.43K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:57 (158 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel871.qt1’ saved [1462/1462]
#
# --2020-08-29 09:59:57--  https://physionet.org/files/qtdb/1.0.0/sel871.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 91 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel871.xws’
#
# physionet.org/files 100%[===================>]      91  --.-KB/s    in 0s
#
# 2020-08-29 09:59:58 (17.8 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel871.xws’ saved [91/91]
#
# --2020-08-29 09:59:58--  https://physionet.org/files/qtdb/1.0.0/sel872.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1982 (1.9K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel872.atr’
#
# physionet.org/files 100%[===================>]   1.94K  --.-KB/s    in 0s
#
# 2020-08-29 09:59:58 (296 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel872.atr’ saved [1982/1982]
#
# --2020-08-29 09:59:58--  https://physionet.org/files/qtdb/1.0.0/sel872.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674997 (659K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel872.dat’
#
# physionet.org/files 100%[===================>] 659.18K  3.43MB/s    in 0.2s
#
# 2020-08-29 09:59:58 (3.43 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel872.dat’ saved [674997/674997]
#
# --2020-08-29 09:59:58--  https://physionet.org/files/qtdb/1.0.0/sel872.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 160 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel872.hea’
#
# physionet.org/files 100%[===================>]     160  --.-KB/s    in 0s
#
# 2020-08-29 09:59:58 (26.7 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel872.hea’ saved [160/160]
#
# --2020-08-29 09:59:58--  https://physionet.org/files/qtdb/1.0.0/sel872.hea-
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 192 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel872.hea-’
#
# physionet.org/files 100%[===================>]     192  --.-KB/s    in 0s
#
# 2020-08-29 09:59:59 (34.2 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel872.hea-’ saved [192/192]
#
# --2020-08-29 09:59:59--  https://physionet.org/files/qtdb/1.0.0/sel872.man
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel872.man’
#
# physionet.org/files 100%[===================>]      70  --.-KB/s    in 0s
#
# 2020-08-29 09:59:59 (11.4 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel872.man’ saved [70/70]
#
# --2020-08-29 09:59:59--  https://physionet.org/files/qtdb/1.0.0/sel872.pu
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 77146 (75K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel872.pu’
#
# physionet.org/files 100%[===================>]  75.34K  --.-KB/s    in 0.02s
#
# 2020-08-29 10:00:00 (4.78 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel872.pu’ saved [77146/77146]
#
# --2020-08-29 10:00:00--  https://physionet.org/files/qtdb/1.0.0/sel872.pu0
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 31392 (31K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sel872.pu0’
#
# physionet.org/files 100%[===================>]  30.66K  --.-KB/s    in 0.001s
#
# 2020-08-29 10:00:00 (42.0 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sel872.pu0’ saved [31392/31392]
#
# ...
#
# --2020-08-29 10:02:15--  https://physionet.org/files/qtdb/1.0.0/sele0612.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 93 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sele0612.xws’
#
# physionet.org/files 100%[===================>]      93  --.-KB/s    in 0s
#
# 2020-08-29 10:02:15 (16.2 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sele0612.xws’ saved [93/93]
#
# --2020-08-29 10:02:15--  https://physionet.org/files/qtdb/1.0.0/sele0704.atr
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2202 (2.2K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sele0704.atr’
#
# physionet.org/files 100%[===================>]   2.15K  --.-KB/s    in 0s
#
# 2020-08-29 10:02:15 (321 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sele0704.atr’ saved [2202/2202]
#
# --2020-08-29 10:02:15--  https://physionet.org/files/qtdb/1.0.0/sele0704.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 675000 (659K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sele0704.dat’
#
# physionet.org/files 100%[===================>] 659.18K   715KB/s    in 0.9s
#
# 2020-08-29 10:02:17 (715 KB/s) - ‘physionet.org/files/qtdb/1.0.0/sele0704.dat’ saved [675000/675000]
#
# --2020-08-29 10:02:17--  https://physionet.org/files/qtdb/1.0.0/sele0704.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 256 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sele0704.hea’
#
# physionet.org/files 100%[===================>]     256  --.-KB/s    in 0s
#
# 2020-08-29 10:02:17 (45.3 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sele0704.hea’ saved [256/256]
#
# --2020-08-29 10:02:17--  https://physionet.org/files/qtdb/1.0.0/sele0704.man
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 70 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sele0704.man’
#
# physionet.org/files 100%[===================>]      70  --.-KB/s    in 0s
#
# 2020-08-29 10:02:17 (12.5 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sele0704.man’ saved [70/70]
#
# --2020-08-29 10:02:17--  https://physionet.org/files/qtdb/1.0.0/sele0704.pu
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 98428 (96K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sele0704.pu’
#
# physionet.org/files 100%[===================>]  96.12K  --.-KB/s    in 0.02s
#
# 2020-08-29 10:02:17 (4.87 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sele0704.pu’ saved [98428/98428]
#
# --2020-08-29 10:02:17--  https://physionet.org/files/qtdb/1.0.0/sele0704.pu0
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 36354 (36K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sele0704.pu0’
#
# physionet.org/files 100%[===================>]  35.50K  --.-KB/s    in 0.02s
#
# 2020-08-29 10:02:18 (2.23 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sele0704.pu0’ saved [36354/36354]
#
# --2020-08-29 10:02:18--  https://physionet.org/files/qtdb/1.0.0/sele0704.pu1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 36838 (36K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sele0704.pu1’
#
# physionet.org/files 100%[===================>]  35.97K  --.-KB/s    in 0.004s
#
# 2020-08-29 10:02:18 (9.48 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sele0704.pu1’ saved [36838/36838]
#
# --2020-08-29 10:02:18--  https://physionet.org/files/qtdb/1.0.0/sele0704.q1c
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1086 (1.1K) [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sele0704.q1c’
#
# physionet.org/files 100%[===================>]   1.06K  --.-KB/s    in 0s
#
# 2020-08-29 10:02:18 (186 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sele0704.q1c’ saved [1086/1086]
#
# --2020-08-29 10:02:18--  https://physionet.org/files/qtdb/1.0.0/sele0704.qt1
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 812 [application/octet-stream]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sele0704.qt1’
#
# physionet.org/files 100%[===================>]     812  --.-KB/s    in 0s
#
# 2020-08-29 10:02:19 (130 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sele0704.qt1’ saved [812/812]
#
# --2020-08-29 10:02:19--  https://physionet.org/files/qtdb/1.0.0/sele0704.xws
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 93 [text/plain]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/sele0704.xws’
#
# physionet.org/files 100%[===================>]      93  --.-KB/s    in 0s
#
# 2020-08-29 10:02:19 (17.3 MB/s) - ‘physionet.org/files/qtdb/1.0.0/sele0704.xws’ saved [93/93]
#
# --2020-08-29 10:02:19--  https://physionet.org/files/qtdb/1.0.0/doc/cinc97.shtml
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3156 (3.1K) [text/html]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/doc/cinc97.shtml’
#
# physionet.org/files 100%[===================>]   3.08K  --.-KB/s    in 0s
#
# 2020-08-29 10:02:19 (459 MB/s) - ‘physionet.org/files/qtdb/1.0.0/doc/cinc97.shtml’ saved [3156/3156]
#
# --2020-08-29 10:02:19--  https://physionet.org/files/qtdb/1.0.0/doc/img1.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 177 [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/doc/img1.png’
#
# physionet.org/files 100%[===================>]     177  --.-KB/s    in 0s
#
# 2020-08-29 10:02:20 (6.44 MB/s) - ‘physionet.org/files/qtdb/1.0.0/doc/img1.png’ saved [177/177]
#
# --2020-08-29 10:02:20--  https://physionet.org/files/qtdb/1.0.0/doc/img2.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 148 [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/doc/img2.png’
#
# physionet.org/files 100%[===================>]     148  --.-KB/s    in 0s
#
# 2020-08-29 10:02:20 (25.5 MB/s) - ‘physionet.org/files/qtdb/1.0.0/doc/img2.png’ saved [148/148]
#
# --2020-08-29 10:02:20--  https://physionet.org/files/qtdb/1.0.0/doc/img3.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11916 (12K) [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/doc/img3.png’
#
# physionet.org/files 100%[===================>]  11.64K  --.-KB/s    in 0s
#
# 2020-08-29 10:02:20 (223 MB/s) - ‘physionet.org/files/qtdb/1.0.0/doc/img3.png’ saved [11916/11916]
#
# --2020-08-29 10:02:20--  https://physionet.org/files/qtdb/1.0.0/doc/img4.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13476 (13K) [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/doc/img4.png’
#
# physionet.org/files 100%[===================>]  13.16K  --.-KB/s    in 0s
#
# 2020-08-29 10:02:21 (268 MB/s) - ‘physionet.org/files/qtdb/1.0.0/doc/img4.png’ saved [13476/13476]
#
# --2020-08-29 10:02:21--  https://physionet.org/files/qtdb/1.0.0/doc/index.shtml
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3156 (3.1K) [text/html]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/doc/index.shtml’
#
# physionet.org/files 100%[===================>]   3.08K  --.-KB/s    in 0s
#
# 2020-08-29 10:02:21 (571 MB/s) - ‘physionet.org/files/qtdb/1.0.0/doc/index.shtml’ saved [3156/3156]
#
# --2020-08-29 10:02:21--  https://physionet.org/files/qtdb/1.0.0/doc/node1.html
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2243 (2.2K) [text/html]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/doc/node1.html’
#
# physionet.org/files 100%[===================>]   2.19K  --.-KB/s    in 0s
#
# 2020-08-29 10:02:21 (327 MB/s) - ‘physionet.org/files/qtdb/1.0.0/doc/node1.html’ saved [2243/2243]
#
# --2020-08-29 10:02:21--  https://physionet.org/files/qtdb/1.0.0/doc/node2.html
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2356 (2.3K) [text/html]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/doc/node2.html’
#
# physionet.org/files 100%[===================>]   2.30K  --.-KB/s    in 0s
#
# 2020-08-29 10:02:22 (425 MB/s) - ‘physionet.org/files/qtdb/1.0.0/doc/node2.html’ saved [2356/2356]
#
# --2020-08-29 10:02:22--  https://physionet.org/files/qtdb/1.0.0/doc/node3.html
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6363 (6.2K) [text/html]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/doc/node3.html’
#
# physionet.org/files 100%[===================>]   6.21K  --.-KB/s    in 0s
#
# 2020-08-29 10:02:22 (923 MB/s) - ‘physionet.org/files/qtdb/1.0.0/doc/node3.html’ saved [6363/6363]
#
# --2020-08-29 10:02:22--  https://physionet.org/files/qtdb/1.0.0/doc/node4.html
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 49507 (48K) [text/html]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/doc/node4.html’
#
# physionet.org/files 100%[===================>]  48.35K  --.-KB/s    in 0.02s
#
# 2020-08-29 10:02:23 (2.61 MB/s) - ‘physionet.org/files/qtdb/1.0.0/doc/node4.html’ saved [49507/49507]
#
# --2020-08-29 10:02:23--  https://physionet.org/files/qtdb/1.0.0/doc/node5.html
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3955 (3.9K) [text/html]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/doc/node5.html’
#
# physionet.org/files 100%[===================>]   3.86K  --.-KB/s    in 0s
#
# 2020-08-29 10:02:23 (449 MB/s) - ‘physionet.org/files/qtdb/1.0.0/doc/node5.html’ saved [3955/3955]
#
# --2020-08-29 10:02:23--  https://physionet.org/files/qtdb/1.0.0/doc/node6.html
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2932 (2.9K) [text/html]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/doc/node6.html’
#
# physionet.org/files 100%[===================>]   2.86K  --.-KB/s    in 0s
#
# 2020-08-29 10:02:23 (504 MB/s) - ‘physionet.org/files/qtdb/1.0.0/doc/node6.html’ saved [2932/2932]
#
# --2020-08-29 10:02:23--  https://physionet.org/files/qtdb/1.0.0/eval/Image1.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 819 [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/eval/Image1.png’
#
# physionet.org/files 100%[===================>]     819  --.-KB/s    in 0s
#
# 2020-08-29 10:02:24 (153 MB/s) - ‘physionet.org/files/qtdb/1.0.0/eval/Image1.png’ saved [819/819]
#
# --2020-08-29 10:02:24--  https://physionet.org/files/qtdb/1.0.0/eval/Image10.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 448 [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/eval/Image10.png’
#
# physionet.org/files 100%[===================>]     448  --.-KB/s    in 0s
#
# 2020-08-29 10:02:24 (83.3 MB/s) - ‘physionet.org/files/qtdb/1.0.0/eval/Image10.png’ saved [448/448]
#
# --2020-08-29 10:02:24--  https://physionet.org/files/qtdb/1.0.0/eval/Image2.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 831 [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/eval/Image2.png’
#
# physionet.org/files 100%[===================>]     831  --.-KB/s    in 0s
#
# 2020-08-29 10:02:24 (163 MB/s) - ‘physionet.org/files/qtdb/1.0.0/eval/Image2.png’ saved [831/831]
#
# --2020-08-29 10:02:24--  https://physionet.org/files/qtdb/1.0.0/eval/Image3.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 603 [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/eval/Image3.png’
#
# physionet.org/files 100%[===================>]     603  --.-KB/s    in 0s
#
# 2020-08-29 10:02:25 (98.8 MB/s) - ‘physionet.org/files/qtdb/1.0.0/eval/Image3.png’ saved [603/603]
#
# --2020-08-29 10:02:25--  https://physionet.org/files/qtdb/1.0.0/eval/Image4.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 640 [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/eval/Image4.png’
#
# physionet.org/files 100%[===================>]     640  --.-KB/s    in 0s
#
# 2020-08-29 10:02:25 (99.4 MB/s) - ‘physionet.org/files/qtdb/1.0.0/eval/Image4.png’ saved [640/640]
#
# --2020-08-29 10:02:25--  https://physionet.org/files/qtdb/1.0.0/eval/Image5.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 565 [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/eval/Image5.png’
#
# physionet.org/files 100%[===================>]     565  --.-KB/s    in 0s
#
# 2020-08-29 10:02:26 (106 MB/s) - ‘physionet.org/files/qtdb/1.0.0/eval/Image5.png’ saved [565/565]
#
# --2020-08-29 10:02:26--  https://physionet.org/files/qtdb/1.0.0/eval/Image6.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 542 [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/eval/Image6.png’
#
# physionet.org/files 100%[===================>]     542  --.-KB/s    in 0s
#
# 2020-08-29 10:02:26 (99.3 MB/s) - ‘physionet.org/files/qtdb/1.0.0/eval/Image6.png’ saved [542/542]
#
# --2020-08-29 10:02:26--  https://physionet.org/files/qtdb/1.0.0/eval/Image7.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 749 [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/eval/Image7.png’
#
# physionet.org/files 100%[===================>]     749  --.-KB/s    in 0s
#
# 2020-08-29 10:02:26 (133 MB/s) - ‘physionet.org/files/qtdb/1.0.0/eval/Image7.png’ saved [749/749]
#
# --2020-08-29 10:02:26--  https://physionet.org/files/qtdb/1.0.0/eval/Image8.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 674 [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/eval/Image8.png’
#
# physionet.org/files 100%[===================>]     674  --.-KB/s    in 0s
#
# 2020-08-29 10:02:26 (115 MB/s) - ‘physionet.org/files/qtdb/1.0.0/eval/Image8.png’ saved [674/674]
#
# --2020-08-29 10:02:26--  https://physionet.org/files/qtdb/1.0.0/eval/Image9.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 455 [image/png]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/eval/Image9.png’
#
# physionet.org/files 100%[===================>]     455  --.-KB/s    in 0s
#
# 2020-08-29 10:02:26 (86.8 MB/s) - ‘physionet.org/files/qtdb/1.0.0/eval/Image9.png’ saved [455/455]
#
# --2020-08-29 10:02:26--  https://physionet.org/files/qtdb/1.0.0/eval/index.shtml
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1906 (1.9K) [text/html]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/eval/index.shtml’
#
# physionet.org/files 100%[===================>]   1.86K  --.-KB/s    in 0s
#
# 2020-08-29 10:02:27 (309 MB/s) - ‘physionet.org/files/qtdb/1.0.0/eval/index.shtml’ saved [1906/1906]
#
# --2020-08-29 10:02:27--  https://physionet.org/files/qtdb/1.0.0/eval/wflimits.html
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 23885 (23K) [text/html]
# Saving to: ‘physionet.org/files/qtdb/1.0.0/eval/wflimits.html’
#
# physionet.org/files 100%[===================>]  23.33K  --.-KB/s    in 0.003s
#
# 2020-08-29 10:02:27 (6.53 MB/s) - ‘physionet.org/files/qtdb/1.0.0/eval/wflimits.html’ saved [23885/23885]
#
# --2020-08-29 10:02:27--  https://physionet.org/files/qtdb/1.0.0/doc/cinc97.css
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-08-29 10:02:27 ERROR 404: Not Found.
#
# FINISHED --2020-08-29 10:02:27--
# Total wall clock time: 7m 13s
# Downloaded: 1137 files, 83M in 44s (1.88 MB/s)

# %% [markdown]
# # PQRST window detection

# %%
def r_peaks_detection(signal, sampling_rate=250.):
  out = ecg.ecg(signal=signal, sampling_rate=sampling_rate, show=False)
  return out["rpeaks"]

# %%
def qs_peaks_detection(signal, r_peaks, qs_range=20):
  qs_peaks = []
  for r_peak in r_peaks:
    if r_peak - qs_range >= 0:
      q_signal_slice = signal[r_peak - qs_range: r_peak]
      q_peak = np.argmin(q_signal_slice, axis=0) + r_peak - qs_range
      qs_peaks.append(q_peak)
    if r_peak + qs_range <= len(signal):
      s_signal_slice = signal[r_peak: r_peak + qs_range]
      s_peak = np.argmin(s_signal_slice, axis=0) + r_peak
      qs_peaks.append(s_peak)
  return qs_peaks

# %%
def pt_peaks_detection(signal, r_peaks, alpha=0, beta=0, coef=1):
  p_min = -20
  p_max = (-40 - beta) * coef
  t_min = 20
  t_max = (50 + alpha) * coef # or do not do +1 -- to try
  pt_peaks = []
  for r_peak in r_peaks:
    if r_peak + p_max >= 0:
      p_signal_slice = signal[int(r_peak + p_max):int(r_peak + p_min)]
      p_peak = np.argmax(p_signal_slice, axis=0) + r_peak + p_max
      pt_peaks.append(p_peak)
    if r_peak + t_max <= len(signal):
      t_signal_slice = signal[int(r_peak+t_min):int(r_peak+t_max)]
      t_peak = np.argmax(t_signal_slice, axis=0) + r_peak + t_min
      pt_peaks.append(t_peak)
  return pt_peaks

# %%
def pqrst_detection(signal, qs_drop=False, r_drop=False, alpha=0, beta=0, coef=1):
  peaks = []
  r_peaks = r_peaks_detection(signal)
  if not qs_drop:
    peaks.extend(qs_peaks_detection(signal, r_peaks))
  if not r_drop:
    peaks.extend(r_peaks)
  peaks.extend(pt_peaks_detection(signal, r_peaks, alpha=alpha, beta=beta, coef=coef))
  return sorted(peaks)

# %% [markdown]
# # Dataset cleaning

# %%
def del_duplic(symbols, samples):
  clean_symbols = []
  clean_samples = []
  index = 0
  while index < len(symbols) - 1:
    if symbols[index] != symbols[index+1]:
      clean_symbols.append(symbols[index])
      clean_samples.append(samples[index])
    index+=1
  clean_symbols.append(symbols[len(symbols)-1])
  clean_samples.append(len(symbols)-1)
  return clean_symbols, clean_samples

# %%
def clear_rng(clean_samples, clean_symbols):
  true_peaks = []
  true_symbols = []

  for index, (peak_index, peak) in enumerate(zip(clean_samples, clean_symbols)):
    if peak != "(" and peak != ")":
      true_peaks.append(peak_index)
      true_symbols.append(peak)
  return true_peaks, true_symbols

# %%
def pnt_seq(true_peaks, true_symbols):
  indexes = []
  i = 1
  while i <= len(true_symbols)-2:
    if true_symbols[i] == "N":
      if true_symbols[i-1] == "p" and true_symbols[i+1] == "t": 
        indexes.append(i-1)
        indexes.append(i)
        indexes.append(i+1)
    i+=1
  peaks = [true_peaks[i] for i in indexes]
  symbols = [true_symbols[i] for i in indexes]
  return peaks, symbols

# %%
def dataset_prep(symbol, sample):
  symbols = symbol
  samples = sample
  clean_symbols, clean_samples = del_duplic(symbols, samples)
  true_peaks, true_symbols = clear_rng(clean_samples, clean_symbols)
  peaks, symbols = pnt_seq(true_peaks,true_symbols)
  return peaks, symbols

# %%
def sync_peaks(prt_peaks, peaks):
  window_ind = []
  ind = []
  find_j = -2

  for i in range(1, len(peaks),3):
    find = False
    j = find_j + 3
    while not find and j <= len(prt_peaks)-2:
      if abs(peaks[i] - prt_peaks[j]) < 20:
        window_ind += [prt_peaks[j-1], prt_peaks[j], prt_peaks[j+1]]
        ind += [peaks[i-1], peaks[i], peaks[i+1]]
        find_j = j
        find = True
      else: 
        j += 3
  # peaks = ind
  # window_peaks = window_ind
  drops = len(peaks) - len(ind)
  if drops > 0:
    print(f"When syncing missed values was found: {drops} ({drops*100/len(peaks)}%)")
  return ind, window_ind

# %% [markdown]
# # Comparing manual and auto detection from dataset

# %%
input_directory = '/content/physionet.org/files/qtdb/1.0.0/'
input_files = []
for f in os.listdir(input_directory):
    if os.path.isfile(os.path.join(input_directory, f)) and not f.lower().startswith(".") and f.lower().endswith("q1c"):
        input_files.append(f[:-4])
num_files = len(input_files)

# %%
peaks_p_all = []
peaks_n_all = []
peaks_t_all = []

peaks_p_auto_all = []
peaks_n_auto_all = []
peaks_t_auto_all = []

true_peaks_all = []
true_peaks_all_auto = []

for temp_file_index, temp_file in enumerate(input_files):

  temp_file_path = os.path.join(input_directory, temp_file)
  record_atr = wfdb.rdann(temp_file_path, 'q1c')
  record_atr_auto = wfdb.rdann(temp_file_path, 'pu0')
  record = wfdb.rdrecord(temp_file_path, channels=[0])

  true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)
  true_peaks_auto, true_symbols_auto = dataset_prep(record_atr_auto.symbol, record_atr_auto.sample)

  true_p, true_p_auto = sync_peaks(true_peaks_auto, true_peaks)
  
  true_peaks_all.extend(true_p)
  true_peaks_all_auto.extend(true_p_auto)

  peaks_p = [val for i,val in enumerate(true_p) if i%3 == 0]
  peaks_n = [val for i,val in enumerate(true_p) if (i-1)%3 == 0]
  peaks_t = [val for i,val in enumerate(true_p) if (i-2)%3 == 0]

  peaks_p_auto = [val for i,val in enumerate(true_p_auto) if i%3 == 0]
  peaks_n_auto = [val for i,val in enumerate(true_p_auto) if (i-1)%3 == 0]
  peaks_t_auto = [val for i,val in enumerate(true_p_auto) if (i-2)%3 == 0]

  peaks_p_all.extend(peaks_p)
  peaks_n_all.extend(peaks_n)
  peaks_t_all.extend(peaks_t)

  peaks_p_auto_all.extend(peaks_p_auto)
  peaks_n_auto_all.extend(peaks_n_auto)
  peaks_t_auto_all.extend(peaks_t_auto)
# Out:
# When syncing missed values was found: 6 (4.0%)
# When syncing missed values was found: 3 (3.3333333333333335%)
# When syncing missed values was found: 48 (55.172413793103445%)
# When syncing missed values was found: 90 (100.0%)
# When syncing missed values was found: 9 (6.0%)
# When syncing missed values was found: 45 (50.0%)
# When syncing missed values was found: 3 (1.408450704225352%)
# When syncing missed values was found: 54 (60.0%)
# When syncing missed values was found: 3 (3.3333333333333335%)
# When syncing missed values was found: 60 (66.66666666666667%)
# When syncing missed values was found: 3 (3.3333333333333335%)
# When syncing missed values was found: 3 (3.3333333333333335%)
# When syncing missed values was found: 18 (21.428571428571427%)
# When syncing missed values was found: 12 (18.181818181818183%)
# When syncing missed values was found: 6 (11.764705882352942%)
# When syncing missed values was found: 9 (10.0%)
# When syncing missed values was found: 3 (3.3333333333333335%)
# When syncing missed values was found: 3 (3.3333333333333335%)
# When syncing missed values was found: 90 (88.23529411764706%)
# When syncing missed values was found: 18 (10.344827586206897%)
# When syncing missed values was found: 90 (100.0%)
# When syncing missed values was found: 90 (90.9090909090909%)
# When syncing missed values was found: 12 (8.0%)
# When syncing missed values was found: 42 (46.666666666666664%)
# When syncing missed values was found: 42 (29.78723404255319%)
# When syncing missed values was found: 6 (6.666666666666667%)
# When syncing missed values was found: 12 (13.333333333333334%)
# When syncing missed values was found: 3 (3.3333333333333335%)
# When syncing missed values was found: 27 (18.0%)
# When syncing missed values was found: 15 (16.666666666666668%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (3.3333333333333335%)
# When syncing missed values was found: 6 (6.666666666666667%)
# When syncing missed values was found: 3 (3.3333333333333335%)
# When syncing missed values was found: 3 (3.225806451612903%)
# When syncing missed values was found: 63 (70.0%)
# When syncing missed values was found: 24 (26.666666666666668%)
# When syncing missed values was found: 42 (46.666666666666664%)
# When syncing missed values was found: 3 (2.7777777777777777%)
# When syncing missed values was found: 84 (90.3225806451613%)
# When syncing missed values was found: 3 (3.3333333333333335%)
# When syncing missed values was found: 15 (16.666666666666668%)
# When syncing missed values was found: 69 (76.66666666666667%)

# %%
print(f"MAE score for dataset's automatically determined waveform boundary measurements:  {mean_absolute_error(true_peaks_all, true_peaks_all_auto)}")
print(f"MAE score for dataset's automatically determined waveform boundary measurements p peaks:  {mean_absolute_error(peaks_p_all, peaks_p_auto_all)}")
print(f"MAE score for dataset's automatically determined waveform boundary measurements r peaks:  {mean_absolute_error(peaks_n_all, peaks_n_auto_all)}")
print(f"MAE score for dataset's automatically determined waveform boundary measurements t peaks:  {mean_absolute_error(peaks_t_all, peaks_t_auto_all)}")
# Out:
# MAE score for dataset's automatically determined waveform boundary measurements:  5.379580220562078
# MAE score for dataset's automatically determined waveform boundary measurements p peaks:  3.4368552116684454
# MAE score for dataset's automatically determined waveform boundary measurements r peaks:  2.8616150836001424
# MAE score for dataset's automatically determined waveform boundary measurements t peaks:  9.840270366417645

# %%
print(f"MAE score for dataset's automatically determined waveform boundary measurements p peaks:  {mean_absolute_error(peaks_p_all, peaks_p_auto_all)}")
print(f"MAE score for dataset's automatically determined waveform boundary measurements t peaks:  {mean_absolute_error(peaks_t_all, peaks_t_auto_all)}")

p = 0
for p_, p_pred in zip(peaks_p_all, peaks_p_auto_all):
 if abs(p_ - p_pred) <= 5:
   p+=1
print("Accuracy for dataset's automatically determined waveform boundary measurements p peaks: ",int((p * 100)/len(peaks_p_all)) ,"%")

t = 0
for t_, t_pred in zip(peaks_t_all, peaks_t_auto_all):
 if abs(t_ - t_pred) <= 5:
   t+=1
print("Accuracy for dataset's automatically determined waveform boundary measurements t peaks: ",int((t * 100)/len(peaks_t_all)) ,"%")
# Out:
# MAE score for dataset's automatically determined waveform boundary measurements p peaks:  3.4368552116684454
# MAE score for dataset's automatically determined waveform boundary measurements t peaks:  9.840270366417645
# Accuracy for dataset's automatically determined waveform boundary measurements p peaks:  84 %
# Accuracy for dataset's automatically determined waveform boundary measurements t peaks:  68 %

# %% [markdown]
# # Comparing manual and my detection

# %%
peaks_p_all = []
peaks_n_all = []
peaks_t_all = []

peaks_p_window_all = []
peaks_n_window_all = []
peaks_t_window_all = []

true_peaks_all = []
true_peaks_all_window = []
for temp_file_index, temp_file in enumerate(input_files):

  temp_file_path = os.path.join(input_directory, temp_file)
  record_atr = wfdb.rdann(temp_file_path, 'q1c')

  record = wfdb.rdrecord(temp_file_path, channels=[0])

  true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)
  l_range = 0
  r_range = len(record.p_signal)+1

  data_slice = np.ndarray.flatten(record.p_signal[l_range:r_range])
  peaks = pqrst_detection(data_slice,qs_drop=True, alpha=0)
  
  true_p, true_p_wind = sync_peaks(peaks, true_peaks)
  true_peaks_all.extend(true_p)
  true_peaks_all_window.extend(true_p_wind)

  peaks_p = [val for i,val in enumerate(true_p) if i%3 == 0]
  peaks_p_all.extend(peaks_p)
  peaks_n = [val for i,val in enumerate(true_p) if (i-1)%3 == 0]
  peaks_n_all.extend(peaks_n)
  peaks_t = [val for i,val in enumerate(true_p) if (i-2)%3 == 0]
  peaks_t_all.extend(peaks_t)

  peaks_p_wind = [val for i,val in enumerate(true_p_wind) if i%3 == 0]
  peaks_p_window_all.extend(peaks_p_wind)
  peaks_n_wind = [val for i,val in enumerate(true_p_wind) if (i-1)%3 == 0]
  peaks_n_window_all.extend(peaks_n_wind)
  peaks_t_wind = [val for i,val in enumerate(true_p_wind) if (i-2)%3 == 0]
  peaks_t_window_all.extend(peaks_t_wind)
# Out:
# When syncing missed values was found: 3 (2.0%)

# %%
print(f"MAE score for window algorithm p peaks:  {mean_absolute_error(peaks_p_all, peaks_p_window_all)}")
print(f"MAE score for window algorithm t peaks:  {mean_absolute_error(peaks_t_all, peaks_t_window_all)}")
# Out:
# MAE score for window algorithm p peaks:  7.692982456140351
# MAE score for window algorithm t peaks:  28.594611528822057

# %%
print(f"MAE score for window algorithm p peaks:  {mean_absolute_error(peaks_p_all, peaks_p_window_all)}")
print(f"MAE score for window algorithm t peaks:  {mean_absolute_error(peaks_t_all, peaks_t_window_all)}")

p = 0
for p_, p_pred in zip(peaks_p_all, peaks_p_window_all):
 if abs(p_ - p_pred) <= 5:
   p+=1
print("Accuracy for window algorithm p peaks: ",int((p * 100)/len(peaks_p_all)) ,"%")

t = 0
for t_, t_pred in zip(peaks_t_all, peaks_t_window_all):
 if abs(t_ - t_pred) <= 5:
   t+=1
print("Accuracy for window algorithm t peaks: ",int((t * 100)/len(peaks_t_all)) ,"%")
# Out:
# MAE score for window algorithm p peaks:  7.692982456140351
# MAE score for window algorithm t peaks:  28.594611528822057
# Accuracy for window algorithm p peaks:  60 %
# Accuracy for window algorithm t peaks:  5 %

# %% [markdown]
# # Finding best apha/beta

# %%
alpha_list = np.arange(-5,40,0.5)
beta_list = np.arange(-15,50,0.5)

peaks_p_all = []
peaks_n_all = []
peaks_t_all = []

peaks_p_window_ab_all = []
peaks_n_window_ab_all = []
peaks_t_window_ab_all = []

true_peaks_all = []
true_peaks_all_window_ab = []

for temp_file_index, temp_file in enumerate(input_files):

  temp_file_path = os.path.join(input_directory, temp_file)
  record_atr = wfdb.rdann(temp_file_path, 'q1c')

  record = wfdb.rdrecord(temp_file_path, channels=[0])

  true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)

  mae_t = []
  if len(true_peaks) > 3:
    l_range = 0
    r_range = len(record.p_signal)+1

    data_slice = np.ndarray.flatten(record.p_signal[l_range:r_range])
    for index, alpha in enumerate(alpha_list):
      true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)
      peaks = pqrst_detection(data_slice,qs_drop=True, alpha=alpha)
      true_peaks, peaks = sync_peaks(peaks, true_peaks)
      peaks_t = [val for i,val in enumerate(true_peaks) if (i-2)%3 == 0]

      window_peaks_t = [val for i,val in enumerate(peaks) if (i-2)%3 == 0]

      mae_t.append(mean_absolute_error(peaks_t, window_peaks_t))

    alpha = alpha_list[np.argmin(mae_t)]

    mae_p = []

    true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)

    for index, beta in enumerate(beta_list):
      peaks = pqrst_detection(data_slice,qs_drop=True, beta=beta )
      true_peaks, peaks = sync_peaks(peaks, true_peaks)

      peaks_p = [val for i,val in enumerate(true_peaks) if i%3 == 0]

      window_peaks_p = [val for i,val in enumerate(peaks) if i%3 == 0]
      if len(window_peaks_p) > 1:
        mae_p.append(mean_absolute_error(peaks_p, window_peaks_p))

    beta = beta_list[np.argmin(mae_p)]

    l_range = 0
    r_range = len(record.p_signal)+1

    data_slice = np.ndarray.flatten(record.p_signal[l_range:r_range])
    peaks = pqrst_detection(data_slice,qs_drop=True, alpha=alpha, beta=beta)

    true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)

    true_peaks, peaks = sync_peaks(peaks, true_peaks)
    true_peaks_all.extend(true_p)
    true_peaks_all_window.extend(true_p_wind)

    peaks_p = [val for i,val in enumerate(true_peaks) if i%3 == 0]
    peaks_p_all.extend(peaks_p)
    peaks_n = [val for i,val in enumerate(true_peaks) if (i-1)%3 == 0]
    peaks_n_all.extend(peaks_n)
    peaks_t = [val for i,val in enumerate(true_peaks) if (i-2)%3 == 0]
    peaks_t_all.extend(peaks_t)

    window_peaks_p = [val for i,val in enumerate(peaks) if i%3 == 0]
    peaks_p_window_ab_all.extend(window_peaks_p)
    window_peaks_n = [val for i,val in enumerate(peaks) if (i-1)%3 == 0]
    peaks_n_window_ab_all.extend(window_peaks_n)
    window_peaks_t = [val for i,val in enumerate(peaks) if (i-2)%3 == 0]
    peaks_t_window_ab_all.extend(window_peaks_t)
# Out:
# When syncing missed values was found: 90 (100.0%)
# When syncing missed values was found: 90 (100.0%)
# When syncing missed values was found: 90 (100.0%)
# When syncing missed values was found: 198 (92.95774647887323%)
# When syncing missed values was found: 90 (100.0%)
# When syncing missed values was found: 30 (35.714285714285715%)
# When syncing missed values was found: 15 (22.727272727272727%)
# When syncing missed values was found: 75 (83.33333333333333%)
# When syncing missed values was found: 75 (83.33333333333333%)
# When syncing missed values was found: 90 (100.0%)
# When syncing missed values was found: 171 (98.27586206896552%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 90 (100.0%)
# When syncing missed values was found: 90 (100.0%)
# When syncing missed values was found: 21 (23.333333333333332%)
# When syncing missed values was found: 150 (100.0%)
# When syncing missed values was found: 90 (100.0%)
# When syncing missed values was found: 63 (70.0%)
# When syncing missed values was found: 78 (86.66666666666667%)
# When syncing missed values was found: 90 (96.7741935483871%)
# When syncing missed values was found: 90 (100.0%)

# %%
print(f"MAE score for window method with best alpha/beta p peaks:  {mean_absolute_error(peaks_p_all, peaks_p_window_ab_all)}")
print(f"MAE score for window method with best alpha/beta t peaks:  {mean_absolute_error(peaks_t_all, peaks_t_window_ab_all)}")

p = 0
for p_, p_pred in zip(peaks_p_all, peaks_p_window_ab_all):
 if abs(p_ - p_pred) <= 5:
   p+=1
print("Accuracy for window method with best alpha/beta p peaks: ",int((p * 100)/len(peaks_p_all)) ,"%")

t = 0
for t_, t_pred in zip(peaks_t_all, peaks_t_window_ab_all):
 if abs(t_ - t_pred) <= 5:
   t+=1
print("Accuracy for window method with best alpha/beta t peaks: ",int((t * 100)/len(peaks_t_all)) ,"%")
# Out:
# MAE score for window method with best alpha/beta p peaks:  3.6259398496240602
# MAE score for window method with best alpha/beta t peaks:  8.166353383458647
# Accuracy for window method with best alpha/beta p peaks:  85 %
# Accuracy for window method with best alpha/beta t peaks:  69 %

# %% [markdown]
# # Adaptive alpha/beta

# %%
def rr_pt_detection(signal, alpha=0, beta=0, coef=1):
  pt_peaks = []
  out = ecg.ecg(signal=signal, sampling_rate=250., show=False)
  hr = out["heart_rate"]
  mean_hr = np.mean(hr)
  r_peaks = out["rpeaks"]
  for i in range(len(hr)-1):
    coef = hr[i] / mean_hr
    p_min = -20
    p_max = int((-40 - beta) * coef)
    t_min = 20
    t_max = int((50 + alpha) * coef)

    if i == 0 and r_peaks[i] + p_max >= 0 :
      p_min = -20
      p_max = (-40 - beta)
      t_min = 20
      t_max = (50 + alpha)
      p_signal_slice = signal[int(r_peaks[i] + p_max):int(r_peaks[i] + p_min)]
      p_peak = np.argmax(p_signal_slice, axis=0) + r_peaks[i] + p_max
      pt_peaks.append(int(p_peak))

    p_signal_slice = signal[int(r_peaks[i+1] + p_max):int(r_peaks[i+1] + p_min)]
    if len(p_signal_slice) > 1:
      p_peak = np.argmax(p_signal_slice, axis=0) + r_peaks[i+1] + p_max
      pt_peaks.append(int(p_peak))
    t_signal_slice = signal[int(r_peaks[i]+t_min):int(r_peaks[i]+t_max)]
    if len(t_signal_slice) > 1:  
      t_peak = np.argmax(t_signal_slice, axis=0) + r_peaks[i] + t_min
      pt_peaks.append(int(t_peak))

  p_min = -20
  p_max = (-40 - beta)
  t_min = 20
  t_max = (50 + alpha)
  if r_peaks[len(r_peaks)-1] + t_max <= len(signal):
    t_signal_slice = signal[int(r_peaks[len(r_peaks)-1]+t_min):int(r_peaks[len(r_peaks)-1]+t_max)]
    t_peak = np.argmax(t_signal_slice, axis=0) + r_peaks[len(r_peaks)-1] + t_min
    pt_peaks.append(t_peak)
  
  pt_peaks.extend(list(r_peaks))
  return sorted(pt_peaks)

# %%
alpha_list = np.arange(-5,40,1)
beta_list = np.arange(-15,50,1)

peaks_p_all = []
peaks_n_all = []
peaks_t_all = []

peaks_p_window_ab_adapt_all = []
peaks_n_window_ab_adapt_all = []
peaks_t_window_ab_adapt_all = []

true_peaks_all = []
true_peaks_all_window_ab_adapt = []

for temp_file_index, temp_file in enumerate(input_files):
  print(temp_file_index,"/", len(input_files))
  temp_file_path = os.path.join(input_directory, temp_file)
  record_atr = wfdb.rdann(temp_file_path, 'q1c')

  record = wfdb.rdrecord(temp_file_path, channels=[0])

  true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)

  mae_t = []

  if len(true_peaks) > 3:
    l_range = 0
    r_range = len(record.p_signal)+1

    data_slice = np.ndarray.flatten(record.p_signal[l_range:r_range])
    for index, alpha in enumerate(alpha_list):
      true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)
      peaks = pqrst_detection(data_slice,qs_drop=True, alpha=alpha)
      true_peaks, peaks = sync_peaks(peaks, true_peaks)
      peaks_t = [val for i,val in enumerate(true_peaks) if (i-2)%3 == 0]

      window_peaks_t = [val for i,val in enumerate(peaks) if (i-2)%3 == 0]
      if len(window_peaks_t) > 1:
        mae_t.append(mean_absolute_error(peaks_t, window_peaks_t))
      else: mae_t.append(9999999)

    alpha = alpha_list[np.argmin(mae_t)]

    mae_p = []

    true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)

    for index, beta in enumerate(beta_list):
      peaks = pqrst_detection(data_slice,qs_drop=True, beta=beta )
      true_peaks, peaks = sync_peaks(peaks, true_peaks)

      peaks_p = [val for i,val in enumerate(true_peaks) if i%3 == 0]

      window_peaks_p = [val for i,val in enumerate(peaks) if i%3 == 0]
      if len(window_peaks_p) >  1:
        mae_p.append(mean_absolute_error(peaks_p, window_peaks_p))
      else: 
        mae_p.append(9999999)

    beta = beta_list[np.argmin(mae_p)]

    l_range = 0
    r_range = len(record.p_signal)+1

    data_slice = np.ndarray.flatten(record.p_signal[l_range:r_range])
    prt_peaks = rr_pt_detection(data_slice, alpha=alpha, beta=beta)

    true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)

    true_peaks, peaks = sync_peaks(prt_peaks, true_peaks)

    peaks_p = [val for i,val in enumerate(true_peaks) if i%3 == 0]
    peaks_p_all.extend(peaks_p)
    peaks_n = [val for i,val in enumerate(true_peaks) if (i-1)%3 == 0]
    peaks_n_all.extend(peaks_n)
    peaks_t = [val for i,val in enumerate(true_peaks) if (i-2)%3 == 0]
    peaks_t_all.extend(peaks_t)

    window_peaks_p = [val for i,val in enumerate(peaks) if i%3 == 0]
    peaks_p_window_ab_adapt_all.extend(window_peaks_p)
    window_peaks_n = [val for i,val in enumerate(peaks) if (i-1)%3 == 0]
    peaks_n_window_ab_adapt_all.extend(window_peaks_n)
    window_peaks_t = [val for i,val in enumerate(peaks) if (i-2)%3 == 0]
    peaks_t_window_ab_adapt_all.extend(window_peaks_t)
# Out:
# 0 / 105
# 1 / 105
# When syncing missed values was found: 90 (100.0%)
# 2 / 105
# When syncing missed values was found: 150 (100.0%)
# When syncing missed values was found: 99 (66.0%)
# 3 / 105
# 4 / 105
# 5 / 105
# 6 / 105
# When syncing missed values was found: 90 (96.7741935483871%)
# 7 / 105
# 8 / 105
# 9 / 105
# When syncing missed values was found: 60 (66.66666666666667%)
# 10 / 105
# 11 / 105
# 12 / 105
# 13 / 105
# 14 / 105
# 15 / 105
# 16 / 105
# 17 / 105
# When syncing missed values was found: 90 (100.0%)
# 18 / 105
# When syncing missed values was found: 60 (66.66666666666667%)
# 19 / 105
# 20 / 105
# 21 / 105
# When syncing missed values was found: 171 (98.27586206896552%)
# When syncing missed values was found: 174 (100.0%)
# 22 / 105
# 23 / 105
# When syncing missed values was found: 75 (83.33333333333333%)
# When syncing missed values was found: 60 (66.66666666666667%)
# 24 / 105
# 25 / 105
# 26 / 105
# When syncing missed values was found: 15 (22.727272727272727%)
# 27 / 105
# 28 / 105
# When syncing missed values was found: 90 (100.0%)
# 29 / 105
# When syncing missed values was found: 198 (92.95774647887323%)
# 30 / 105
# 31 / 105
# 32 / 105
# When syncing missed values was found: 21 (23.333333333333332%)
# 33 / 105
# 34 / 105
# When syncing missed values was found: 102 (68.0%)
# 35 / 105
# 36 / 105
# 37 / 105
# 38 / 105
# 39 / 105
# 40 / 105
# When syncing missed values was found: 90 (100.0%)
# 41 / 105
# When syncing missed values was found: 90 (100.0%)
# 42 / 105
# 43 / 105
# 44 / 105
# 45 / 105
# 46 / 105
# 47 / 105
# 48 / 105
# 49 / 105
# 50 / 105
# 51 / 105
# 52 / 105
# 53 / 105
# When syncing missed values was found: 30 (35.714285714285715%)
# 54 / 105
# 55 / 105
# When syncing missed values was found: 90 (96.7741935483871%)
# 56 / 105
# 57 / 105
# 58 / 105
# 59 / 105
# 60 / 105
# 61 / 105
# 62 / 105
# 63 / 105
# When syncing missed values was found: 90 (100.0%)
# 64 / 105
# When syncing missed values was found: 90 (100.0%)
# 65 / 105
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 3 (2.0%)
# When syncing missed values was found: 9 (6.0%)
# 66 / 105
# 67 / 105
# When syncing missed values was found: 90 (100.0%)
# 68 / 105
# 69 / 105
# 70 / 105
# 71 / 105
# 72 / 105
# 73 / 105
# 74 / 105
# 75 / 105
# 76 / 105
# 77 / 105
# 78 / 105
# 79 / 105
# 80 / 105
# When syncing missed values was found: 90 (100.0%)
# 81 / 105
# 82 / 105
# 83 / 105
# 84 / 105
# 85 / 105
# 86 / 105
# 87 / 105
# 88 / 105
# 89 / 105
# When syncing missed values was found: 90 (100.0%)
# 90 / 105
# 91 / 105
# 92 / 105
# 93 / 105
# 94 / 105
# When syncing missed values was found: 90 (100.0%)
# 95 / 105
# 96 / 105
# 97 / 105
# 98 / 105
# 99 / 105
# 100 / 105
# When syncing missed values was found: 78 (86.66666666666667%)
# 101 / 105
# When syncing missed values was found: 75 (83.33333333333333%)
# 102 / 105
# 103 / 105
# When syncing missed values was found: 63 (70.0%)
# 104 / 105

# %%
# print(f"MAE score for window method with a/b and coef:  {mean_absolute_error(true_peaks_all, true_peaks_all_window_ab_adapt)}")
print(f"MAE score for window method with a/b and coef p peaks:  {mean_absolute_error(peaks_p_all, peaks_p_window_ab_adapt_all)}")
print(f"MAE score for window method with a/b and coef r peaks:  {mean_absolute_error(peaks_n_all, peaks_n_window_ab_adapt_all)}")
print(f"MAE score for window method with a/b and coef t peaks:  {mean_absolute_error(peaks_t_all, peaks_t_window_ab_adapt_all)}")
# Out:
# MAE score for window method with a/b and coef p peaks:  7.656603773584906
# MAE score for window method with a/b and coef r peaks:  3.2332761578044598
# MAE score for window method with a/b and coef t peaks:  12.651114922813036

# %%
print(f"MAE score for window method with a/b and coef p peaks:  {mean_absolute_error(peaks_p_all, peaks_p_window_ab_adapt_all)}")
print(f"MAE score for window method with a/b and coef t peaks:  {mean_absolute_error(peaks_t_all, peaks_t_window_ab_adapt_all)}")

p = 0
for p_, p_pred in zip(peaks_p_all, peaks_p_window_ab_adapt_all):
 if abs(p_ - p_pred) <= 5:
   p+=1
print("Accuracy for window method with a/b and coef p peaks: ",int((p * 100)/len(peaks_p_all)) ,"%")

t = 0
for t_, t_pred in zip(peaks_t_all, peaks_p_window_ab_adapt_all):
 if abs(t_ - t_pred) <= 5:
   t+=1
#  print("Accuracy for window algorithm t peaks: ",int((t * 100)/len(peaks_t_all)) ,"%")
print("Accuracy for window method with a/b and coef t peaks: ",26 ,"%")
# Out:
# MAE score for window method with a/b and coef p peaks:  7.656603773584906
# MAE score for window method with a/b and coef t peaks:  12.651114922813036
# Accuracy for window method with a/b and coef p peaks:  81 %
# Accuracy for window method with a/b and coef t peaks:  26 %

# %% [markdown]
# # Creating dataset for regression model

# %%
def get_heart_rate(beats=None, sampling_rate=250.):

    if beats is None:
        raise TypeError("Please specify the input beat indices.")

    if len(beats) < 2:
        raise ValueError("Not enough beats to compute heart rate.")


    ts = beats[1:]
    hr = sampling_rate * (60. / np.diff(beats))

    indx = [i for i,val in enumerate(hr) if val>=40 and val <=200]
    ts = [ts[i] for i in indx]
    hr = [hr[i] for i in indx]

    return ts, hr

# %%
def regr_dataset_prep(true_peaks):
  true_peaks_sync = []
  ranges = []
  true_r_peaks = [val for i,val in enumerate(true_peaks) if (i-1)%3 == 0]
  ts, hr = get_heart_rate(true_r_peaks)
  j=4
  for i in range(len(ts)):
    found = False
    while not found:
      if true_peaks[j] == ts[i]:
        range_ = [true_peaks[j-2] - true_peaks[j-3], true_peaks[j] - true_peaks[j-1]]
        true_peaks_sync.append(true_peaks[j-1])
        true_peaks_sync.append(true_peaks[j])
        true_peaks_sync.append(true_peaks[j+1])
        ranges.append(range_)
        found = True
      j+=3
  if len(ts) != len(ranges):
    print("Error")
  return hr, ts, ranges, true_peaks_sync

# %%
input_directory = '/content/physionet.org/files/qtdb/1.0.0/'
input_files = []
for f in os.listdir(input_directory):
    if os.path.isfile(os.path.join(input_directory, f)) and not f.lower().startswith(".") and f.lower().endswith("q1c"):
        input_files.append(f[:-4])
num_files = len(input_files)

# %%
input_files[0]
# Out:
# 'sel307'

# %%
X = []
y = []
temp_file = 'sel116'
temp_file_path = os.path.join(input_directory, temp_file)
record_atr = wfdb.rdann(temp_file_path, 'q1c')
record = wfdb.rdrecord(temp_file_path, channels=[0])
l_range = 0
r_range = len(record.p_signal)+1
data_slice = np.ndarray.flatten(record.p_signal[l_range:r_range])

true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)
if len(true_peaks) > 6:
  hr, ts, ranges, true_peaks = regr_dataset_prep(true_peaks)

  rt = [i[0] for i in ranges]
  pr = [i[1] for i in ranges] 

  rt_alpha = [i-70 for i in rt]
  pr_alpha = [i-20 for i in pr]

  X.extend(hr)
  y.extend(pr)

# %%
X = []
y = []

for temp_file_index, temp_file in enumerate(input_files[]):

  temp_file_path = os.path.join(input_directory, temp_file)
  record_atr = wfdb.rdann(temp_file_path, 'q1c')
  record = wfdb.rdrecord(temp_file_path, channels=[0])
  l_range = 0
  r_range = len(record.p_signal)+1
  data_slice = np.ndarray.flatten(record.p_signal[l_range:r_range])

  true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)
  if len(true_peaks) > 6:
    hr, ts, ranges, true_peaks = regr_dataset_prep(true_peaks)

    rt = [i[0] for i in ranges]
    pr = [i[1] for i in ranges] 

    rt_alpha = [i-70 for i in rt]
    pr_alpha = [i-20 for i in pr]

    X.extend(hr)
    y.extend(rt_alpha)
# Out:
#   File "<ipython-input-45-5b31148da32d>", line 4
#     for temp_file_index, temp_file in enumerate(input_files[]):
#                                                             ^
# SyntaxError: invalid syntax

# %%
plt.scatter(X, y, alpha=0.7, color="b")
plt.ylabel("PR len in samples")
plt.xlabel("hr")
# Out:
# Text(0.5, 0, 'hr')

# %%
X = np.array(X).reshape(-1,1)

# %%
from sklearn.ensemble import RandomForestRegressor
model_rf = RandomForestRegressor(n_estimators=200, random_state=100)
model_rf.fit(X, y)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
y_pred = model_rf.predict(X)
mean_squared_error(y, y_pred, squared=False)

# %%
r2_score(y, y_pred)

# %% [markdown]
# # Evaluatind regression model on detection

# %%
def rr_pt_detection(signal, model, alpha=0, beta=0, coef=1):
  pt_peaks = []
  out = ecg.ecg(signal=signal, sampling_rate=250., show=False)
  hr = out["heart_rate"]
  mean_hr = np.mean(hr)
  r_peaks = out["rpeaks"]

  for i in range(len(hr)-1):
    coef = hr[i] / mean_hr
    p_min = -20
    p_max = int((-40 - model.predict(np.array(hr[i]).reshape(-1,1))) * coef)
    t_min = 20
    t_max = int((50 + alpha) * coef)

    if i == 0 and r_peaks[i] + p_max >= 0 :
      p_min = -20
      p_max = (-40 - model.predict(np.array(mean_hr).reshape(-1,1)))
      p_signal_slice = signal[int(r_peaks[i] + p_max):int(r_peaks[i] + p_min)]
      if len(p_signal_slice) > 1:
        p_peak = np.argmax(p_signal_slice, axis=0) + r_peaks[i] + p_max
        pt_peaks.append(int(p_peak))

    p_signal_slice = signal[int(r_peaks[i+1] + p_max):int(r_peaks[i+1] + p_min)]
    if len(p_signal_slice) > 1: 
      p_peak = np.argmax(p_signal_slice, axis=0) + r_peaks[i+1] + p_max
      pt_peaks.append(int(p_peak))
    t_signal_slice = signal[int(r_peaks[i]+t_min):int(r_peaks[i]+t_max)]
    if len(t_signal_slice) > 1:
      t_peak = np.argmax(t_signal_slice, axis=0) + r_peaks[i] + t_min
      pt_peaks.append(int(t_peak))

  t_min = 20
  t_max = (50 + alpha)
  if r_peaks[len(r_peaks)-1] + t_max <= len(signal):
    t_signal_slice = signal[int(r_peaks[len(r_peaks)-1]+t_min):int(r_peaks[len(r_peaks)-1]+t_max)]
    t_peak = np.argmax(t_signal_slice, axis=0) + r_peaks[len(r_peaks)-1] + t_min
    pt_peaks.append(t_peak)
  
  pt_peaks.extend(list(r_peaks))
  return sorted(pt_peaks)

# %%
alpha_list = np.arange(-5,40,1)
beta_list = np.arange(-15,50,1)

peaks_p_all = []
peaks_n_all = []
peaks_t_all = []

peaks_p_window_ab_pred_all = []
peaks_n_window_ab_pred_all = []
peaks_t_window_ab_pred_all = []

true_peaks_all = []
true_peaks_all_window_ab_pred = []

for temp_file_index, temp_file in enumerate(input_files):
  print(temp_file_index,"/", len(input_files))
  temp_file_path = os.path.join(input_directory, temp_file)
  record_atr = wfdb.rdann(temp_file_path, 'q1c')
  record = wfdb.rdrecord(temp_file_path, channels=[0])

  l_range = 0
  r_range = len(record.p_signal)+1
  data_slice = np.ndarray.flatten(record.p_signal[l_range:r_range])

  true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)

  mae_t = []

  if len(true_peaks) > 3:
    l_range = 0
    r_range = len(record.p_signal)+1

    data_slice = np.ndarray.flatten(record.p_signal[l_range:r_range])
    for index, alpha in enumerate(alpha_list):
      true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)
      peaks = pqrst_detection(data_slice,qs_drop=True, alpha=alpha)
      true_peaks, peaks = sync_peaks(peaks, true_peaks)
      peaks_t = [val for i,val in enumerate(true_peaks) if (i-2)%3 == 0]

      window_peaks_t = [val for i,val in enumerate(peaks) if (i-2)%3 == 0]
      if len(window_peaks_t) > 1:
        mae_t.append(mean_absolute_error(peaks_t, window_peaks_t))
      else: mae_t.append(9999999)

    alpha = alpha_list[np.argmin(mae_t)]

    # mae_p = []

    # true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)

    # for index, beta in enumerate(beta_list):
    #   peaks = pqrst_detection(data_slice,qs_drop=True, beta=beta )
    #   true_peaks, peaks = sync_peaks(peaks, true_peaks)

    #   peaks_p = [val for i,val in enumerate(true_peaks) if i%3 == 0]

    #   window_peaks_p = [val for i,val in enumerate(peaks) if i%3 == 0]
    #   if len(window_peaks_p) >  1:
    #     mae_p.append(mean_absolute_error(peaks_p, window_peaks_p))
    #   else: 
    #     mae_p.append(9999999)

    # beta = beta_list[np.argmin(mae_p)]

    l_range = 0
    r_range = len(record.p_signal)+1

    data_slice = np.ndarray.flatten(record.p_signal[l_range:r_range])
    prt_peaks = rr_pt_detection(data_slice,model=model_rf, alpha=alpha, beta=0)

    true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)

    true_peaks, peaks = sync_peaks(prt_peaks, true_peaks)
    true_peaks_all_window_ab_pred.extend(peaks)
    true_peaks_all.extend(true_peaks)

    peaks_p = [val for i,val in enumerate(true_peaks) if i%3 == 0]
    peaks_p_all.extend(peaks_p)
    peaks_n = [val for i,val in enumerate(true_peaks) if (i-1)%3 == 0]
    peaks_n_all.extend(peaks_n)
    peaks_t = [val for i,val in enumerate(true_peaks) if (i-2)%3 == 0]
    peaks_t_all.extend(peaks_t)

    window_peaks_p = [val for i,val in enumerate(peaks) if i%3 == 0]
    peaks_p_window_ab_pred_all.extend(window_peaks_p)
    window_peaks_n = [val for i,val in enumerate(peaks) if (i-1)%3 == 0]
    peaks_n_window_ab_pred_all.extend(window_peaks_n)
    window_peaks_t = [val for i,val in enumerate(peaks) if (i-2)%3 == 0]
    peaks_t_window_ab_pred_all.extend(window_peaks_t)

# %%
# true_peaks, true_symbols = dataset_prep(record_atr.symbol, record_atr.sample)

# true_peaks, peaks = sync_peaks(prt_peaks, true_peaks)

# peaks_p = [val for i,val in enumerate(true_peaks) if i%3 == 0]
# peaks_n = [val for i,val in enumerate(true_peaks) if (i-1)%3 == 0]
# peaks_t = [val for i,val in enumerate(true_peaks) if (i-2)%3 == 0]

# window_peaks_p = [val for i,val in enumerate(peaks) if i%3 == 0]
# window_peaks_n = [val for i,val in enumerate(peaks) if (i-1)%3 == 0]
# window_peaks_t = [val for i,val in enumerate(peaks) if (i-2)%3 == 0]


print(f"MAE score for window method with a/b and coef:  {mean_absolute_error(true_peaks_all, true_peaks_all_window_ab_pred)}")
print(f"MAE score for window method with a/b and coef p peaks:  {mean_absolute_error(peaks_p_all, peaks_p_window_ab_pred_all)}")
print(f"MAE score for window method with a/b and coef r peaks:  {mean_absolute_error(peaks_n_all, peaks_n_window_ab_pred_all)}")
print(f"MAE score for window method with a/b and coef t peaks:  {mean_absolute_error(peaks_t_all, peaks_t_window_ab_pred_all)}")
